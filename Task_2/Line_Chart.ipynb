# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikhAyaan69/Internship/blob/main/Task_2/Line_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Line Chart 1**

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Datasets/flight_delays.csv")
x=df['Month']
y=df['AA']
plt.plot(x,y,'--b')

# %% [markdown]
# ### **Line Chart 2**

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Datasets/fifa.csv")
x=df['Date']
y=df['ARG']
plt.plot(x,y,'r')

# %% [markdown]
# ### **Line Chart 3**

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/drive/MyDrive/Datasets/ign_scores.csv")
x=df['Platform']
y=df['Action']
plt.plot(x,y,"y")
